# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

dataframe = pd.read_csv("2015_Air_quality_in_northern_Taiwan.csv")
dataframe

dataframe["month"] = pd.DatetimeIndex(dataframe["time"]).month
dataframe["time_hours"] = pd.DatetimeIndex(dataframe["time"]).time

dataframe

dataframe.replace("",float("nan"), inplace=True)
dataframe.replace("0",float("nan"), inplace=True)
dataframe.replace(".#$",float("nan"), inplace=True, regex=True)
dataframe.replace(".x$",float("nan"), inplace=True, regex=True)
df = dataframe.dropna()
df

df["UVB"] = df["UVB"].astype(float)
df["UVB"].dtypes

new_dataframe =df.groupby(["month","time_hours"])["UVB"].max().reset_index()
new_dataframe

plt.figure(figsize=(10,8))
heatmap_df = pd.pivot_table(values = "UVB", index="time_hours",columns="month",data=new_dataframe)
sns.heatmap(heatmap_df,cmap = "plasma")
# Out:
# C:\Users\91982\AppData\Local\Temp\ipykernel_15608\14725973.py:6: DtypeWarning: Columns (10,14,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframe = pd.read_csv("2015_Air_quality_in_northern_Taiwan.csv")
# C:\Users\91982\AppData\Local\Temp\ipykernel_15608\14725973.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["UVB"] = df["UVB"].astype(float)
# <Axes: xlabel='month', ylabel='time_hours'>

# %%
df["SO2"] = df["SO2"].astype(float)
df["SO2"].dtypes

df["CO"] = df["CO"].astype(float)
df["CO"].dtypes

final_dataframe = df.groupby(["month","time_hours"])["CO","SO2"].max().reset_index()
final_dataframe

plt.figure(figsize=(10,8))
heat_map_Co = pd.pivot_table(values="CO",index="time_hours",columns="month",data=final_dataframe)
sns.heatmap(heat_map_Co,cmap="plasma")
# Out:
# C:\Users\91982\AppData\Local\Temp\ipykernel_15608\2778505472.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["SO2"] = df["SO2"].astype(float)
# C:\Users\91982\AppData\Local\Temp\ipykernel_15608\2778505472.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["CO"] = df["CO"].astype(float)
# C:\Users\91982\AppData\Local\Temp\ipykernel_15608\2778505472.py:7: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   final_dataframe = df.groupby(["month","time_hours"])["CO","SO2"].max().reset_index()
# <Axes: xlabel='month', ylabel='time_hours'>
